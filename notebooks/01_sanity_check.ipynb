# %% [markdown]
# # Sanity Check For downloading and cleaning SPY data.
# ## plot of cleaned data

# %%
from pathlib import Path
import matplotlib.pyplot as plt
import pandas as pd

ROOT = Path().resolve().parent #current working directory

DATA_PATH = ROOT / "data" / "processed"

df = pd.read_csv(DATA_PATH / "SPY_clean.csv", index_col=0, parse_dates=True)
df["close"].plot(title="SPY Price")
plt.show()
